# %%
a = rand(6,6)
# Out:
# 6×6 Matrix{Float64}:
#  0.428714   0.714739   0.493108  0.114614  0.311467  0.981088
#  0.0726325  0.0296438  0.368552  0.878692  0.763307  0.728171
#  0.954604   0.0391231  0.839042  0.982125  0.341973  0.954392
#  0.203163   0.496956   0.437375  0.199838  0.556232  0.723909
#  0.239776   0.547405   0.879998  0.916707  0.624773  0.35154
#  0.400971   0.946098   0.349487  0.597362  0.937105  0.392702

# %%
a[1:size(a)[2],1]
# Out:
# 6-element Vector{Float64}:
#  0.4287144504723972
#  0.07263250960919909
#  0.954603510909891
#  0.2031634556723313
#  0.23977557621161028
#  0.4009713075968224
